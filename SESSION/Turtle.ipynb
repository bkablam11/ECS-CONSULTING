# %% [markdown]
# ##############################
# ##### Tortue
# ##############################
#
# ##############################
# ##### Activité 1 - Bouge ta tortue !
# ##############################<br>
# [chaine](https://www.youtube.com/channel/UC6PiFyqBiUjiJ7Q3DRSW2Wg)
# <br>[exercise](https://pdfprof.com/FR_Documents/PDF_1PDFprof_Doc__Document_Gratuits_PDF_Free.php?q=-1PDF57129-exercice+corrig%C3%A9+python+turtle+debutant+pdf)
# <br>[base](https://pdfprof.com/)
# <br>[git](https://github.com/orgs/exo7math/repositories?type=all)

# %%
# Début du code
# Drawing P Y

from turtle import *
import turtle

width(5)    # Epaisseur du trait

# Lettre "P"

color('red')

left(90)        # 90 degrés à gauche
forward(200)    # On avance

right(90)
forward(100)

right(90)
forward(100)

right(90)
forward(100)

up()

# Fin du code 

# Lettre "Y"

color('blue')

goto(200,0)
down()
setheading(90)
forward(120)
left(30)
forward(75)
backward(75)
right(60)
forward(75)

exitonclick()

# %% [markdown]
# ##############################
# ##### Tortue
# ##############################
#
# ##############################
# ##### Activité 2 - Boucle "pour"
# ##############################

# %%
##############################
# Question 1

from turtle import *

# Un pentagone
width(5)
color('blue')

for i in range(5):
    forward(100)
    left(72)


##############################
# Question 2

# Un autre pentagone
color('red')

longueur = 200
angle = 72
for i in range(5):
    forward(longueur)
    left(angle)


##############################
# Question 3

# Un dodecagone (12 côtés quoi)

color("purple")
n = 12
angle = 360/n
for i in range(n):
    forward(100)
    left(angle)


##############################
# Question 4

# Une spirale

color("green")
longueur = 10
for i in range(25):
    forward(longueur)
    left(40)
    longueur = longueur + 10

exitonclick()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# File <string>:8, in forward(distance)
#
# File c:\users\assoumane\appdata\local\programs\python\python38\lib\turtle.py:1637, in TNavigator.forward(self, distance)
#    1617 """Move the turtle forward by the specified distance.
#    1618
#    1619 Aliases: forward | fd
#    (...)
#    1635 (-50.00,0.00)
#    1636 """
# -> 1637 self._go(distance)
#
# File c:\users\assoumane\appdata\local\programs\python\python38\lib\turtle.py:1605, in TNavigator._go(self, distance)
#    1604 ende = self._position + self._orient * distance
# -> 1605 self._goto(ende)
#
# File c:\users\assoumane\appdata\local\programs\python\python38\lib\turtle.py:3176, in RawTurtle._goto(self, end)
#    3175 if self._drawing:
# -> 3176     screen._drawline(self.drawingLineItem,
#    3177                      (start, self._position),
#    3178                      self._pencolor, self._pensize, top)
#    3179 self._update()
#
# File c:\users\assoumane\appdata\local\programs\python\python38\lib\turtle.py:545, in TurtleScreenBase._drawline(self, lineitem, coordlist, fill, width, top)
#     544         cl.append(-y * self.yscale)
# --> 545     self.cv.coords(lineitem, *cl)
#     546 if fill is not None:
#
# File <string>:1, in coords(self, *args, **kw)
#
# File c:\users\assoumane\appdata\local\programs\python\python38\lib\tkinter\__init__.py:2761, in Canvas.coords(self, *args)
#    2758 # XXX Should use _flatten on args
#    2759 return [self.tk.getdouble(x) for x in
#    2760                    self.tk.splitlist(
# -> 2761            self.tk.call((self._w, 'coords') + args))]
#
# TclError: invalid command name ".!canvas"
#
# During handling of the above exception, another exception occurred:
#
# Terminator                                Traceback (most recent call last)
# Input In [2], in <cell line: 48>()
#      47 longueur = 10
#      48 for i in range(25):
# ---> 49     forward(longueur)
#      50     left(40)
#      51     longueur = longueur + 10
#
# File <string>:12, in forward(distance)
#
# Terminator:

# %% [markdown]
# ##############################
# ##### Tortue
# ##############################
#
#
# ##############################
# ##### Activité 3 - Graphe d'une fonction
# ##############################

# %%
from turtle import *
from math import *

speed("fastest")
width(2)
color('blue')
up()

for x in range(-200,200):
    if x == -199: 
        down()
    y = 1/ 100 * x ** 2   # Parabole
    # y = 100*sin(1/20*x)     # Sinus
    goto(x,y)


exitonclick()

# %% [markdown]
# ##############################
# ##### Tortue
# ##############################
#
# ##############################
# ##### Activité 4 - Boucle pour itérée - Triangle de Sierpinski
# ##############################

# %%
from turtle import *

width(5)
up()
goto(-100,-100)
down()

for i in range(3):
    color("blue")
    forward(256)
    left(120)

    for i in range(3):
        color("red")
        forward(128)
        left(120)

        for i in range(3):
            color("green")
            forward(64)
            left(120)  

            for i in range(3):
                color("orange")
                forward(32)
                left(120)                            

exitonclick()

# %% [markdown]
# ##############################
# ##### Tortue
# ##############################
#
# ##############################
# ##### Activité 5 - Table de multiplications
# ##############################

# %%
from turtle import *
from math import *

speed("fastest")

n = 100
b = 2
r = 200

for i in range(n):
    up()
    goto(r*cos(2*i*pi/n),r*sin(2*i*pi/n))
    down()
    j = (b*i) % n
    goto(r*cos(2*j*pi/n),r*sin(2*j*pi/n))

exitonclick()

# %% [markdown]
# ##############################
# ##### Tortue
# ##############################
#
# ##############################
# ##### Activité 4 - Plusieurs tortues - Courbe de poursuite
# ##############################

# %%
# Préparation

from turtle import *

tortue1 = Turtle()
tortue2 = Turtle()
tortue3 = Turtle()
tortue4 = Turtle()

tortue1.speed("fastest")
tortue2.speed("fastest")
tortue3.speed("fastest")
tortue4.speed("fastest")

tortue1.color('red')
tortue2.color('blue')
tortue3.color('orange')
tortue4.color('green')

# tortue1.width(5)
# tortue2.width(5)
# tortue3.width(5)
# tortue4.width(5)

tortue1.up()
tortue1.goto(-200,-200)
tortue1.down()

tortue2.up()
tortue2.goto(200,-200)
tortue2.down()

tortue3.up()
tortue3.goto(200,200)
tortue3.down()

tortue4.up()
tortue4.goto(-200,200)
tortue4.down()

print(tortue1.position())
print(tortue1.towards(0,0))


# Boucle principale

for i in range(40):

    position1 = tortue1.position()
    position2 = tortue2.position()
    position3 = tortue3.position()
    position4 = tortue4.position()

    tortue1.goto(position2)  # Va à la tortue suivante
    tortue1.goto(position1)       # Revient à sa place

    tortue2.goto(position3)
    tortue2.goto(position2)

    tortue3.goto(position4)
    tortue3.goto(position3)

    tortue4.goto(position1)
    tortue4.goto(position4)

    angle1 = tortue1.towards(position2)  # Récupèrer l'angle
    tortue1.setheading(angle1)   # S'oriente selon cet angle

    angle2 = tortue2.towards(position3)
    tortue2.setheading(angle2)

    angle3 = tortue3.towards(position4)
    tortue3.setheading(angle3)

    angle4 = tortue4.towards(position1)
    tortue4.setheading(angle4)

    tortue1.forward(10)    # Avance
    tortue2.forward(10)
    tortue3.forward(10)
    tortue4.forward(10)

exitonclick()
# Out:
# (-200.00,-200.00)
# 45.0

# %%
##############################
# Tortue
##############################
from turtle import *

from math import *

goto(0,0)
forward(472)
left(90)
forward(400)

##############################
# Activité 1 - 
##############################

def activite_1():
    # reset()
    forward(100)
    left(90)
    forward(100)
    left(90)
    forward(100)
    right(45)
    backward(20)

    up()
    color('red')
    width(5)
    goto(-100,0)
    down()

    forward(100)

    #done()
    exitonclick()

# activite_1()

##############################
# Activité 2 - Boucle pour
##############################

def activite_2():
    # reset()

    width(5)
    color('blue')

    for i in range(5):
        forward(100)
        left(72)

    color('red')

    longueur = 200
    angle = 72
    for i in range(5):
        forward(longueur)
        left(angle)

    color('green')

    longueur = 300
    angle = 72
    for i in range(5):
        forward(longueur)
        left(angle)


    color("purple")
    n = 12
    angle = 360/n
    for i in range(n):
        forward(100)
        left(angle)


    exitonclick()


# activite_2()


##############################
# Activité 3 - Boucle pour itérée Triangle de Sierpinski
##############################



def activite_3():
    # reset()

    width(5)
    up()
    goto(-100,-100)
    down()

    for i in range(3):
        color("blue")
        forward(256)
        left(120)


        for i in range(3):
            color("red")
            forward(128)
            left(120)

            for i in range(3):
                color("green")
                forward(64)
                left(120)  


                for i in range(3):
                    color("orange")
                    forward(32)
                    left(120)                            

    exitonclick()

# activite_3()


##############################
# Activité  - Graphe d'une fonction
##############################

def activite_7():
    speed("fastest")

    for i in range(-200,200):
        x = i
        y = 1/ 100 * x ** 2
        y = 100*sin(0.1*x) 
        goto(x,y)


    exitonclick()

activite_7()



##############################
# Activité 5 - Table de multiplication
##############################



def activite_5():

    speed("fastest")

    n = 100
    b = 2
    R = 200

    for i in range(n):
        up()
        goto(R*cos(2*i*pi/n),R*sin(2*i*pi/n))
        down()
        j = (b*i) % n
        goto(R*cos(2*j*pi/n),R*sin(2*j*pi/n))


    exitonclick()


# activite_5()



##############################
# Activité 4 - Plusieurs tortue - Courbe de poursuite
##############################


    # tortue1 = Turtle()
    # tortue2 = Turtle()

    # tortue1.color('red')
    # tortue2.color('blue')

    # tortue1.forward(100)
    # tortue2.left(90)
    # tortue2.forward(100)

def activite_4():

    tortue1 = Turtle()
    tortue2 = Turtle()
    tortue3 = Turtle()
    tortue4 = Turtle()

    tortue1.speed("fastest")
    tortue2.speed("fastest")
    tortue3.speed("fastest")
    tortue4.speed("fastest")

    tortue3.color('yellow')
    tortue4.color('green')

    tortue1.up()
    tortue1.goto(-200,-200)
    tortue1.down()

    tortue2.up()
    tortue2.goto(200,-200)
    tortue2.down()

    tortue3.up()
    tortue3.goto(200,200)
    tortue3.down()

    tortue4.up()
    tortue4.goto(-200,200)
    tortue4.down()

    print(tortue1.position())
    print(tortue1.towards(0,0))



    for i in range(40):


        position1 = tortue1.position()
        position2 = tortue2.position()
        position3 = tortue3.position()
        position4 = tortue4.position()

        tortue1.goto(position2)  # Va à la tortue suivante
        tortue1.goto(position1)  # Revient à sa place

        tortue2.goto(position3)
        tortue2.goto(position2)

        tortue3.goto(position4)
        tortue3.goto(position3)

        tortue4.goto(position1)
        tortue4.goto(position4)


        angle1 = tortue1.towards(position2)  # Récupèrer l'angle
        tortue1.setheading(angle1)  # S'oriente selon cet angle

        angle2 = tortue2.towards(position3)
        tortue2.setheading(angle2)

        angle3 = tortue3.towards(position4)
        tortue3.setheading(angle3)

        angle4 = tortue4.towards(position1)
        tortue4.setheading(angle4)

        tortue1.forward(10)   # Avance
        tortue2.forward(10)
        tortue3.forward(10)
        tortue4.forward(10)




    exitonclick()


# activite_4()
# Out:
# ----------------------------------------------------------------
# Terminator                     Traceback (most recent call last)
# Input In [44], in <cell line: 142>()
#     137         goto(x,y)
#     140     exitonclick()
# --> 142 activite_7()
#     146 ##############################
#     147 # Activité 5 - Table de multiplication
#     148 ##############################
#     152 def activite_5():
#
# Input In [44], in activite_7()
#     135     y = 1/ 100 * x ** 2
#     136     y = 100*sin(0.1*x)
# --> 137     goto(x,y)
#     140 exitonclick()
#
# File <string>:5, in goto(x, y)
#
# Terminator:

# %%
##############################
# Tortue
##############################

##############################
# Cours - Tortue
##############################

from turtle import *

forward(100)   # On avance
left(90)       # 90 degrés à gauche
forward(50)
width(5)       # Epaisseur du trait
forward(100)
color('red')
right(90)
forward(200)

exitonclick()
# Out:
# ----------------------------------------------------------------
# Terminator                     Traceback (most recent call last)
# Input In [48], in <cell line: 26>()
#      20 exitonclick()
#      22 #################
#      23 # Cours - Plusieurs tortues
#      24 #################
# ---> 26 tortue1 = Turtle()   # Avec un 'T' majuscule !
#      27 tortue2 = Turtle()
#      29 tortue1.color('red')
#
# File c:\users\assoumane\appdata\local\programs\python\python38\lib\turtle.py:3813, in Turtle.__init__(self, shape, undobuffersize, visible)
#    3811 if Turtle._screen is None:
#    3812     Turtle._screen = Screen()
# -> 3813 RawTurtle.__init__(self, Turtle._screen,
#    3814                    shape=shape,
#    3815                    undobuffersize=undobuffersize,
#    3816                    visible=visible)
#
# File c:\users\assoumane\appdata\local\programs\python\python38\lib\turtle.py:2557, in RawTurtle.__init__(self, canvas, shape, undobuffersize, visible)
#    2555 self._undobuffersize = undobuffersize
#    2556 self.undobuffer = Tbuffer(undobuffersize)
# -> 2557 self._update()
#
# File c:\users\assoumane\appdata\local\programs\python\python38\lib\turtle.py:2660, in RawTurtle._update(self)
#    2658     return
#    2659 elif screen._tracing == 1:
# -> 2660     self._update_data()
#    2661     self._drawturtle()
#    2662     screen._update()                  # TurtleScreenBase
#
# File c:\users\assoumane\appdata\local\programs\python\python38\lib\turtle.py:2646, in RawTurtle._update_data(self)
#    2645 def _update_data(self):
# -> 2646     self.screen._incrementudc()
#    2647     if self.screen._updatecounter != 0:
#    2648         return
#
# File c:\users\assoumane\appdata\local\programs\python\python38\lib\turtle.py:1292, in TurtleScreen._incrementudc(self)
#    1290 if not TurtleScreen._RUNNING:
#    1291     TurtleScreen._RUNNING = True
# -> 1292     raise Terminator
#    1293 if self._tracing > 0:
#    1294     self._updatecounter += 1
#
# Terminator:

# %%
#################
# Cours - Plusieurs tortues
#################

tortue1 = Turtle()   # Avec un 'T' majuscule !
tortue2 = Turtle()

tortue1.color('red')
tortue2.color('blue')

tortue1.forward(100)
tortue2.left(90)
tortue2.forward(100)

exitonclick()

# %%
from turtle import *
for i in range(5):
    down()
    for j in range(4):
        forward(20) # avance de 20 pixels
        left(90) # tourne a gauche de 90 degres
    up()
    forward(40) #Avance de 40 en dessinant
mainloop()
